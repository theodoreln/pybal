# %% [markdown]
# ## Load python module

# %%
# Add parent directory to path to import pybal module
import sys
from pathlib import Path

# Add the parent directory (pybal root) to Python path
module_path = Path.cwd().parent
if str(module_path) not in sys.path:
    sys.path.insert(0, str(module_path))

# Import pybal modules
from data.scenario import ScenarioManager, ScenarioConfig
from data.data_load import DataLoader, DataManager

# Import other common libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gams.transfer as gt

print("✓ Pybal modules loaded successfully!")
print(f"  - ScenarioManager, ScenarioConfig")
print(f"  - DataLoader, DataManager")
# Out:
# ✓ Pybal modules loaded successfully!
#   - ScenarioManager, ScenarioConfig
#   - DataLoader, DataManager

# %% [markdown]
# ## Load data

# %%
# Scenario Manager
Manager = ScenarioManager("K:/Projects/25117_SMR_in_DK/Scenarios_AF25/SMR0_AF25")
Manager.summary()
# Out:
# ✓ Detected single scenario: SMR0_AF25
# ============================================================
# Scenario Manager Summary
# ============================================================
# Root Path: K:\Projects\25117_SMR_in_DK\Scenarios_AF25\SMR0_AF25
# Type: Single Scenario
# Total Scenarios: 1
#
# Scenarios:
#   • SMR0_AF25
#     - Path: K:\Projects\25117_SMR_in_DK\Scenarios_AF25\SMR0_AF25
#     - Total GDX Files: 10
#       ↳ BM file: SMR0_AF25-BM.gdx
#       ↳ Basis file: SMR0_AF25-Basis.gdx
#       ↳ Input file: SMR0_AF25-input.gdx
#       ↳ Output file: SMR0_AF25-output.gdx
#       ↳ Output-year files: 6
#         → 2025: SMR0_AF25-output-2025.gdx
#         → 2030: SMR0_AF25-output-2030.gdx
#         → 2035: SMR0_AF25-output-2035.gdx
#         → 2040: SMR0_AF25-output-2040.gdx
#         → 2045: SMR0_AF25-output-2045.gdx
#         → 2050: SMR0_AF25-output-2050.gdx
#
# Common years across all scenarios (6):
#   • 2025
#   • 2030
#   • 2035
#   • 2040
#   • 2045
#   • 2050
# ============================================================

# %%
# Data Manager
Data = DataManager(Manager)
# Or directly with path : Data = DataManager("K:/Projects/25117_SMR_in_DK/Scenarios_AF25/SMR0_AF25")
# Out:
# ============================================================
# Mapping symbols to data files for 1 scenarios:
# ============================================================
# Processing data type: input
# Processing data type: BM
# Warning: Symbol 'THEORETICALFLH_BM' already exists in 'input' file.
# Processing data type: Basis
# c:\Users\tna\Documents\PythonBalmorel\pybal\pybal_venv\Lib\site-packages\gams\transfer\containers\_container.py:73: UserWarning: The GAMS version (50.4.1) differs from the API version (51.2.1).
#   ws = GamsWorkspace()
# c:\Users\tna\Documents\PythonBalmorel\pybal\pybal_venv\Lib\site-packages\gams\transfer\containers\_container.py:73: UserWarning: The GAMS version (50.4.1) differs from the API version (51.2.1).
#   ws = GamsWorkspace()
# Warning: Symbol 'QOBJ' already exists in 'input' file.
# Warning: Symbol 'QOBJnew' already exists in 'input' file.
# Warning: Symbol 'VOBJ' already exists in 'input' file.
# Warning: Symbol 'VOBJnew' already exists in 'input' file.
# Processing data type: output
# Warning: Symbol 'AREA_MEASURES' already exists in 'input' file.
# Warning: Symbol 'ECONSET' already exists in 'input' file.
# Warning: Symbol 'EMISSIONSPRICE_MEASURES' already exists in 'input' file.
# Warning: Symbol 'REGION_MEASURES' already exists in 'input' file.
# Warning: Symbol 'TRANSMISSION_MEASURES' already exists in 'input' file.
# Warning: Symbol 'UNITCAPACITY_MEASURES' already exists in 'input' file.
# Warning: Symbol 'SOLVER_MEASURES' already exists in 'input' file.
# Warning: Symbol 'POLICY_MEASURES' already exists in 'input' file.
# Processing data type: output_year
# Warning: Symbol 'ECONSET' already exists in 'output' file.
# Warning: Symbol 'AREA_MEASURES' already exists in 'output' file.
# Warning: Symbol 'REGION_MEASURES' already exists in 'output' file.
# Warning: Symbol 'TRANSMISSION_MEASURES' already exists in 'output' file.

# %%
# To load all data in the manager (not recommended for large datasets)
#Data._load_all_data()

# %%
# To check the size of the DataManager object as a check if loading all data
from pympler import asizeof
size_bytes = asizeof.asizeof(Data)
size_gb = size_bytes / (1024 ** 3)
print(f"DataManager size: {size_gb:.2f} GB")
# Out:
# DataManager size: 0.99 GB

# %% [markdown]
# ## Extract data

# %%
unit_results = Data.get_symbol('UNITRESULTS_T')
# Out:
# ============================================================
# Loading symbol 'UNITRESULTS_T' for scenarios: All Scenarios
# ============================================================
# c:\Users\tna\Documents\PythonBalmorel\pybal\pybal_venv\Lib\site-packages\gams\transfer\containers\_container.py:73: UserWarning: The GAMS version (50.4.1) differs from the API version (51.2.1).
#   ws = GamsWorkspace()
# c:\Users\tna\Documents\PythonBalmorel\pybal\pybal_venv\Lib\site-packages\gams\transfer\containers\_container.py:73: UserWarning: The GAMS version (50.4.1) differs from the API version (51.2.1).
#   ws = GamsWorkspace()
# c:\Users\tna\Documents\PythonBalmorel\pybal\pybal_venv\Lib\site-packages\gams\transfer\containers\_container.py:73: UserWarning: The GAMS version (50.4.1) differs from the API version (51.2.1).
#   ws = GamsWorkspace()
# c:\Users\tna\Documents\PythonBalmorel\pybal\pybal_venv\Lib\site-packages\gams\transfer\containers\_container.py:73: UserWarning: The GAMS version (50.4.1) differs from the API version (51.2.1).
#   ws = GamsWorkspace()
# c:\Users\tna\Documents\PythonBalmorel\pybal\pybal_venv\Lib\site-packages\gams\transfer\containers\_container.py:73: UserWarning: The GAMS version (50.4.1) differs from the API version (51.2.1).
#   ws = GamsWorkspace()

# %%
unit_results
# Out:
#            Scenario   YYY       CCC   RRR        AAA                  GGG  \
# 0         SMR0_AF25  2035   Denmark  DK_E  DK_CA_KBH  GasTur-EXT-NG-20_29
# 1         SMR0_AF25  2035   Denmark  DK_E  DK_CA_KBH  GasTur-EXT-NG-20_29
# 2         SMR0_AF25  2035   Denmark  DK_E  DK_CA_KBH  GasTur-EXT-NG-20_29
# 3         SMR0_AF25  2035   Denmark  DK_E  DK_CA_KBH  GasTur-EXT-NG-20_29
# 4         SMR0_AF25  2035   Denmark  DK_E  DK_CA_KBH  GasTur-EXT-NG-20_29
# ...             ...   ...       ...   ...        ...                  ...
# 13432798  SMR0_AF25  2030  Portugal  PT_R  PT_R_INDH         INDH_HeatSto
# 13432799  SMR0_AF25  2030  Portugal  PT_R  PT_R_INDH         INDH_HeatSto
# 13432800  SMR0_AF25  2030  Portugal  PT_R  PT_R_INDH         INDH_HeatSto
# 13432801  SMR0_AF25  2030  Portugal  PT_R  PT_R_INDH         INDH_HeatSto
# 13432802  SMR0_AF25  2030  Portugal  PT_R  PT_R_INDH         INDH_HeatSto
#
#               FFF  SSS   TTT                                    ECONSET  \
# 0         NAT_GAS  S02  T002               Electricity generation (GWh)
# 1         NAT_GAS  S02  T002  Electricity generation incl loading (GWh)
# 2         NAT_GAS  S02  T002                       Heat generation (TJ)
# 3         NAT_GAS  S02  T002          Heat generation incl loading (TJ)
# 4         NAT_GAS  S02  T002     Heat generation incl loading + VS (TJ)
# ...           ...  ...   ...                                        ...
# 13432798     HEAT  S25  T011     Heat generation incl loading + VS (TJ)
# 13432799     HEAT  S26  T006     Heat generation incl loading + VS (TJ)
# 13432800     HEAT  S26  T007     Heat generation incl loading + VS (TJ)
# 13432801     HEAT  S26  T009     Heat generation incl loading + VS (TJ)
# 13432802     HEAT  S26  T011     Heat generation incl loading + VS (TJ)
#
#               value
# 0          0.356454
# 1          0.356454
# 2          1.340894
# 3          1.340894
# 4          1.340894
# ...             ...
# 13432798  51.936458
# 13432799 -28.909498
# 13432800  27.464024
# 13432801 -57.818997
# 13432802  54.928047
#
# [13432803 rows x 11 columns]

# %% [markdown]
# ## Analyze data

# %%
# Example to calculate the annual sum of fuel cost internal for specific hydrogen turbines (from timestep results)
unit_results = Data.get_symbol('UNITRESULTS_T')

# Filter GGG column so that is has only values 'GasTur-CON-H2-30_49' and 'GasTur-CON-H2-50'
unit_results = unit_results[unit_results['GGG'].isin(['GasTur-CON-H2-30_49', 'GasTur-CON-H2-50'])].reset_index(drop=True)

# Filter ECONSET column so that it has only value 'Fuel cost internal (m$)'
unit_results = unit_results[unit_results['ECONSET'] == 'Fuel cost internal (m$)'].reset_index(drop=True)

# Remove scenario column for grouping
unit_results = unit_results.drop(columns=['Scenario', 'SSS', 'TTT']).reset_index(drop=True)

# I want the sum over Y, S and T columns of values for all combinations of Scenario, AAA and GGG
sum_values = unit_results.groupby(['YYY', 'CCC', 'RRR', 'AAA', 'GGG', 'FFF', 'ECONSET']).sum().reset_index()

# Delete 0 values
sum_values = sum_values[sum_values['value'] != 0].reset_index(drop=True)
# Out:
# ============================================================
# Loading symbol 'UNITRESULTS_T' for scenarios: All Scenarios
# ============================================================
# C:\Users\tna\AppData\Local\Temp\ipykernel_23876\3507234735.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sum_values = unit_results.groupby(['YYY', 'CCC', 'RRR', 'AAA', 'GGG', 'FFF', 'ECONSET']).sum().reset_index()

# %%
sum_values
# Out:
#      YYY          CCC    RRR       AAA                  GGG       FFF  \
# 0   2040       Norway  NO_SE   NO_SE_A  GasTur-CON-H2-30_49  HYDROGEN
# 1   2040  Switzerland   CH_R      CH_A  GasTur-CON-H2-30_49  HYDROGEN
# 2   2040      Belgium   BE_R      BE_A  GasTur-CON-H2-30_49  HYDROGEN
# 3   2040        Italy   IT_R      IT_A  GasTur-CON-H2-30_49  HYDROGEN
# 4   2045       Norway  NO_SE   NO_SE_A  GasTur-CON-H2-30_49  HYDROGEN
# 5   2045  Switzerland   CH_R      CH_A  GasTur-CON-H2-30_49  HYDROGEN
# 6   2045      Belgium   BE_R      BE_A  GasTur-CON-H2-30_49  HYDROGEN
# 7   2045        Italy   IT_R      IT_A  GasTur-CON-H2-30_49  HYDROGEN
# 8   2050      Germany  DE_CS  DE_CS_A1     GasTur-CON-H2-50  HYDROGEN
# 9   2050      Germany  DE_ME  DE_ME_A1     GasTur-CON-H2-50  HYDROGEN
# 10  2050      Germany  DE_NW  DE_NW_A1     GasTur-CON-H2-50  HYDROGEN
# 11  2050       Norway  NO_SE   NO_SE_A  GasTur-CON-H2-30_49  HYDROGEN
# 12  2050       Norway  NO_SE   NO_SE_A     GasTur-CON-H2-50  HYDROGEN
# 13  2050      Austria   AT_R      AT_A     GasTur-CON-H2-50  HYDROGEN
# 14  2050  Switzerland   CH_R      CH_A     GasTur-CON-H2-50  HYDROGEN
# 15  2050      Belgium   BE_R      BE_A     GasTur-CON-H2-50  HYDROGEN
# 16  2050  Netherlands   NL_R      NL_A     GasTur-CON-H2-50  HYDROGEN
# 17  2050        Italy   IT_R      IT_A     GasTur-CON-H2-50  HYDROGEN
#
#                     ECONSET       value
# 0   Fuel cost internal (m$)   25.910697
# 1   Fuel cost internal (m$)  273.671440
# 2   Fuel cost internal (m$)   79.386970
# 3   Fuel cost internal (m$)    9.564491
# 4   Fuel cost internal (m$)   82.747584
# 5   Fuel cost internal (m$)  280.356726
# 6   Fuel cost internal (m$)  120.332198
# 7   Fuel cost internal (m$)   28.146014
# 8   Fuel cost internal (m$)   68.389851
# 9   Fuel cost internal (m$)    5.574672
# 10  Fuel cost internal (m$)    1.008355
# 11  Fuel cost internal (m$)    0.554619
# 12  Fuel cost internal (m$)  101.777226
# 13  Fuel cost internal (m$)   16.784595
# 14  Fuel cost internal (m$)  464.257687
# 15  Fuel cost internal (m$)  403.461131
# 16  Fuel cost internal (m$)   42.098211
# 17  Fuel cost internal (m$)  269.645845

# %%
# Export sum values to CSV
sum_values.to_csv("internal_fuel_cost.csv")

# %% [markdown]
# ## Output data

# %%
# Soon coming
